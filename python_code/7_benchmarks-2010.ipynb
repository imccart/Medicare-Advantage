# %%
import pandas as pd
import numpy as np

# Read CSV (skip first 10 rows, specify column names)
bench_data = pd.read_csv(
    "data/input/ma/benchmarks/ratebook2010/CountyRate2010.csv",
    skiprows=10,
    names=[
        "ssa", "state", "county_name", "aged_parta",
        "aged_partb", "disabled_parta", "disabled_partb",
        "esrd_ab", "risk_ab"
    ]
)

# Select columns and add numeric NA columns
final_benchmark = (
    bench_data[["ssa", "aged_parta", "aged_partb", "risk_ab"]]
    .assign(
        risk_star5=np.nan,
        risk_star45=np.nan,
        risk_star4=np.nan,
        risk_star35=np.nan,
        risk_star3=np.nan,
        risk_star25=np.nan,
        risk_bonus5=np.nan,
        risk_bonus35=np.nan,
        risk_bonus0=np.nan,
        year=2010
    )
)

print(final_benchmark.head())
