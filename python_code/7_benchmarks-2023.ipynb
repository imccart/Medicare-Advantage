# %%
import pandas as pd
import numpy as np

# Read CSV (skip first 3 rows, specify column names, treat "#N/A" as missing)
bench_data = pd.read_csv(
    "data/input/ma/benchmarks/ratebook2023/CountyRate2023.csv",
    skiprows=3,
    names=[
        "ssa", "state", "county_name",
        "risk_bonus5", "risk_bonus35",
        "risk_bonus0", "esrd_ab"
    ],
    na_values="#N/A"
)

# Select columns and add missing numeric columns
final_benchmark = (
    bench_data[["ssa", "risk_bonus5", "risk_bonus35", "risk_bonus0"]]
    .assign(
        risk_star5=np.nan,
        risk_star45=np.nan,
        risk_star4=np.nan,
        risk_star35=np.nan,
        risk_star3=np.nan,
        risk_star25=np.nan,
        aged_parta=np.nan,
        aged_partb=np.nan,
        risk_ab=np.nan,
        year=2023
    )
)

print(final_benchmark.head())
